# %%
#Set working directory
import os
os.chdir('C://Users//Admin//Downloads')

# %%
# Import pandas library.
import pandas as pd
from pandas import DataFrame

# %%
#The file "nyc-rolling-sales_clean.csvPreview the document" contains New York City 
#property sales data taken from Kaggle (Links to an external site.). 
#The data has already been cleaned and a few columns have been dropped.
#Write your own code in Python that performs the following operations on this dataset:
file = pd.read_csv('nyc-rolling-sales_clean.csv')

# %%
#Create a new column "year of sale" by extracting year information from "SALE DATE" column
file['SALE DATE'] = pd.to_datetime(file['SALE DATE'])
file['year of sale'] = file['SALE DATE'].dt.year
file
# Out:
#         NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0      ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 1      ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 2      ALPHABET CITY  22 STORE BUILDINGS
# 3            CHELSEA  01 ONE FAMILY DWELLINGS
# 4            CHELSEA  01 ONE FAMILY DWELLINGS
# 5            CHELSEA  01 ONE FAMILY DWELLINGS
# 6            CHELSEA  01 ONE FAMILY DWELLINGS
# 7            CHELSEA  02 TWO FAMILY DWELLINGS
# 8            CHELSEA  03 THREE FAMILY DWELLINGS
# 9            CHELSEA  07 RENTALS - WALKUP APARTMENTS
# 10           CHELSEA  07 RENTALS - WALKUP APARTMENTS
# 11           CHELSEA  07 RENTALS - WALKUP APARTMENTS
# 12           CHELSEA  08 RENTALS - ELEVATOR APARTMENTS
# 13           CHELSEA  09 COOPS - WALKUP APARTMENTS
# 14           CHELSEA  21 OFFICE BUILDINGS
# 15           CHELSEA  21 OFFICE BUILDINGS
# 16           CHELSEA  21 OFFICE BUILDINGS
# 17           CHELSEA  21 OFFICE BUILDINGS
# ...

# %%
#Drop the "SALE DATE" column.
file.drop(['SALE DATE'], axis=1, inplace=True)
file
# Out:
#         NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0      ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 1      ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 2      ALPHABET CITY  22 STORE BUILDINGS
# 3            CHELSEA  01 ONE FAMILY DWELLINGS
# 4            CHELSEA  01 ONE FAMILY DWELLINGS
# 5            CHELSEA  01 ONE FAMILY DWELLINGS
# 6            CHELSEA  01 ONE FAMILY DWELLINGS
# 7            CHELSEA  02 TWO FAMILY DWELLINGS
# 8            CHELSEA  03 THREE FAMILY DWELLINGS
# 9            CHELSEA  07 RENTALS - WALKUP APARTMENTS
# 10           CHELSEA  07 RENTALS - WALKUP APARTMENTS
# 11           CHELSEA  07 RENTALS - WALKUP APARTMENTS
# 12           CHELSEA  08 RENTALS - ELEVATOR APARTMENTS
# 13           CHELSEA  09 COOPS - WALKUP APARTMENTS
# 14           CHELSEA  21 OFFICE BUILDINGS
# 15           CHELSEA  21 OFFICE BUILDINGS
# 16           CHELSEA  21 OFFICE BUILDINGS
# 17           CHELSEA  21 OFFICE BUILDINGS
# ...

# %%
#Get dummy encoded columns for 'TAX CLASS AT PRESENT' predictor.
pd.get_dummies(file, columns=['TAX CLASS AT PRESENT'])
# Out:
#         NEIGHBORHOOD                      BUILDING CLASS CATEGORY  BLOCK  LOT  \
# 0      ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS               387  153
# 1      ALPHABET CITY  09 COOPS - WALKUP APARTMENTS                   376   14
# 2      ALPHABET CITY  22 STORE BUILDINGS                             390   34
# 3            CHELSEA  01 ONE FAMILY DWELLINGS                        771   52
# 4            CHELSEA  01 ONE FAMILY DWELLINGS                        772   29
# 5            CHELSEA  01 ONE FAMILY DWELLINGS                        772   29
# 6            CHELSEA  01 ONE FAMILY DWELLINGS                        772   29
# 7            CHELSEA  02 TWO FAMILY DWELLINGS                        769   49
# 8            CHELSEA  03 THREE FAMILY DWELLINGS                      719   67
# 9            CHELSEA  07 RENTALS - WALKUP APARTMENTS                 743   56
# 10           CHELSEA  07 RENTALS - WALKUP APARTMENTS                 764   68
# ...
